# %%
import torch
import torchvision
import torchvision.transforms as transforms

# PyTorch TensorBoard support
from torch.utils.tensorboard import SummaryWriter
from datetime import datetime
from PIL import Image, ImageOps


transform = transforms.Compose(
    [transforms.ToTensor(),
    transforms.Normalize((0.5,), (0.5,))])

# Create datasets for training & validation, download if necessary
training_set = torchvision.datasets.FashionMNIST('./data', train=True, transform=transform, download=True)
validation_set = torchvision.datasets.FashionMNIST('./data', train=False, transform=transform, download=True)

# Create data loaders for our datasets; shuffle for training, not for validation
training_loader = torch.utils.data.DataLoader(training_set, batch_size=1, shuffle=True)
validation_loader = torch.utils.data.DataLoader(validation_set, batch_size=4, shuffle=False)

# Class labels
classes = ('T-shirt/top', 'Trouser', 'Pullover', 'Dress', 'Coat',
        'Sandal', 'Shirt', 'Sneaker', 'Bag', 'Ankle Boot')

# Report split sizes
print('Training set has {} instances'.format(len(training_set)))
print('Validation set has {} instances'.format(len(validation_set)))
# Out:
# Training set has 60000 instances
# Validation set has 10000 instances

# %%
import matplotlib.pyplot as plt
import numpy as np

# Helper function for inline image display
def matplotlib_imshow(img, one_channel=False):
    if one_channel:
        img = img.mean(dim=0)
    img = img / 2 + 0.5     # unnormalize
    npimg = img.numpy()
    if one_channel:
        plt.imshow(npimg, cmap="Greys")
    else:
        plt.imshow(np.transpose(npimg, (1, 2, 0)))

dataiter = iter(training_loader)
images, labels = next(dataiter)

# Create a grid from the images and show them
# img_grid = torchvision.utils.make_grid(images)
# matplotlib_imshow(img_grid, one_channel=True)
# print('  '.join(classes[labels[j]] for j in range(4)))

# %%
def resize(img):
    im = transforms.functional.to_pil_image(img)
    im = im.resize((32, 32), Image.BILINEAR)
    tensor_im = transforms.functional.to_tensor(im)
    if tensor_im.shape[0] == 1:  # If grayscale, convert to RGB
        tensor_im = torch.cat([tensor_im] * 3)
    return tensor_im

# %%
import os
import requests
from pathlib import Path
import pandas as pd
from torch.utils.data import Dataset
from typing import Tuple
import torch
from torchvision.transforms import Compose, Resize, ToTensor, Normalize, RandomResizedCrop

# %%
class TaskDataset(Dataset):
    def __init__(self, transform=None):

        self.ids = []
        self.imgs = []
        self.labels = []

        self.transform = transform

    def __getitem__(self, index) -> Tuple[int, torch.Tensor, int]:
        id_ = self.ids[index]
        img = self.imgs[index]
        if not self.transform is None:
            img = self.transform(img)
        label = self.labels[index]
        return id_, img, label

    def __len__(self):
        return len(self.ids)

# %%
def get_path_to_img_dir():
  img_dir = os.path.join(os.getcwd(), 'resized_images1')
  if not os.path.isdir(img_dir):
      os.mkdir(img_dir)
  return img_dir

# %%
for idx, (X, y) in enumerate(training_loader):
  img = resize(X[0])

  im = transforms.functional.to_pil_image(img)
  im.save(f'{get_path_to_img_dir()}/{idx}.png', format="PNG")

# %%
dataset = torch.load("./ModelStealingPub.pt")

# %%
import random

# %%
representatives = [6842, 10477, 8845, 823, 7902, 25, 5744, 2257, 1396, 2745, 4739, 12647, 4218, 2443, 5576, 6550, 7298, 8989, 7251, 358, 1286, 7849, 2377, 9003, 28, 24, 4569, 11657, 9410, 9139, 9229, 10588, 5296, 9901, 11839, 6483, 11200, 3483, 7170, 12956, 10667, 7697, 6666, 8550, 5135, 7776, 8301, 4021, 911, 1171, 1371, 11063, 791, 8854, 858, 1958, 3969, 4179, 8759, 1611, 6159, 12966, 5021, 9902, 4422, 8595, 4420, 4456, 11009, 1357, 3337, 7906, 685, 6473, 3058, 8183, 10522, 1981, 12758, 12332, 12505, 2578, 1845, 6477, 6772, 9613, 5693, 2299, 5508, 153, 3144, 8127, 12333, 9677, 5012, 221, 11622, 789, 6854]
for i in random.choices(range(len(dataset)), k=150):
    if i not in representatives:
        representatives.append(i)

# %%
def model_stealing():
    SERVER_URL = "http://34.71.138.79:9090"
    ENDPOINT = "/modelstealing"
    URL = SERVER_URL + ENDPOINT

    TEAM_TOKEN = "DdE56eC1EvRwWcuy"

    for image in dataset:
        id_, img, _ = image
        img = img.convert("RGB")
        img.save(f"output/{id_}.png")

    output = []

    for idx, file_name in enumerate(os.listdir('output')):
        if not file_name.endswith('.png'):
            continue
        if idx % 100 == 0:
            print(f'output Progress: {idx} in {len(dataset)}')
        with open(os.path.join('output', file_name), "rb") as img_file:
            response = requests.get(
                URL, files={"file": img_file}, headers={"token": TEAM_TOKEN}
            )

        if response.status_code == 200:
            output.append({"filename": file_name, "embeddings": response.json()["representation"]})

    # for idx, file_name in enumerate(os.listdir('aug')):
    #     if not file_name.endswith('.png'):
    #         continue
    #     if idx % 100 == 0:
    #         print(f'augmentation Progress: {idx} in {len(os.listdir("aug"))}')
    #     with open(os.path.join('aug', file_name), "rb") as img_file:
    #         response = requests.get(
    #             URL, files={"file": img_file}, headers={"token": TEAM_TOKEN}
    #         )

    #     if response.status_code == 200:
    #         output.append({"filename": file_name, "embeddings": response.json()["representation"]})


    df = pd.DataFrame(output, columns=["filename", "embeddings"])
    df.to_csv("output/embeddings.csv", index=False)

# %%
def generate_augmentation(rotate=False, crop=False, color_jitter=False):
    transformations = []
    if rotate:
        transformations.append(transforms.RandomHorizontalFlip(p=1))
    if crop:
        transformations.append(transforms.RandomCrop(size=(32, 32), padding=4))
    if color_jitter:
        transformations.append(transforms.ColorJitter(brightness=0.5, contrast=0.5, saturation=0.5))

    transform = Compose(transformations)

    # Directory where augmented images will be saved
    save_dir = 'aug/'
    os.makedirs(save_dir, exist_ok=True)

    for image in dataset:
        # Apply transformations
        id, img, _ = image
        for i in range(3):
            transformed_image = transform(image)

            # Save the transformed image
            save_path = os.path.join(save_dir, f"{id}_{i}.png")
            transformed_image.save(save_path)

# %%
generate_augmentation(rotate=True, crop=True, color_jitter=True)

# %%
res = model_stealing()
# Out:
# output Progress: 0 in 13000
# output Progress: 100 in 13000
# output Progress: 200 in 13000
# output Progress: 300 in 13000
# output Progress: 400 in 13000
# output Progress: 500 in 13000
# output Progress: 600 in 13000
# output Progress: 700 in 13000
# output Progress: 800 in 13000
# output Progress: 900 in 13000
# output Progress: 1000 in 13000
# output Progress: 1100 in 13000
# output Progress: 1200 in 13000
# output Progress: 1300 in 13000
# output Progress: 1400 in 13000
# output Progress: 1500 in 13000
# output Progress: 1600 in 13000
# output Progress: 1700 in 13000
# output Progress: 1800 in 13000
# output Progress: 1900 in 13000
# output Progress: 2000 in 13000
# output Progress: 2100 in 13000
# output Progress: 2200 in 13000
# output Progress: 2300 in 13000
# output Progress: 2400 in 13000
# output Progress: 2500 in 13000
# output Progress: 2600 in 13000
# output Progress: 2700 in 13000
# output Progress: 2800 in 13000
# output Progress: 2900 in 13000
# output Progress: 3000 in 13000
# output Progress: 3100 in 13000
# output Progress: 3200 in 13000
# output Progress: 3300 in 13000
# output Progress: 3400 in 13000
# output Progress: 3500 in 13000
# output Progress: 3600 in 13000
# output Progress: 3700 in 13000
# output Progress: 3800 in 13000
# output Progress: 3900 in 13000
# output Progress: 4000 in 13000
# output Progress: 4100 in 13000
# output Progress: 4200 in 13000
# output Progress: 4300 in 13000
# output Progress: 4400 in 13000
# output Progress: 4500 in 13000
# output Progress: 4600 in 13000
# output Progress: 4700 in 13000
# output Progress: 4800 in 13000
# output Progress: 4900 in 13000
# output Progress: 5000 in 13000
# output Progress: 5100 in 13000
# output Progress: 5200 in 13000
# output Progress: 5300 in 13000
# output Progress: 5400 in 13000
# output Progress: 5500 in 13000
# output Progress: 5600 in 13000
# output Progress: 5700 in 13000
# output Progress: 5800 in 13000
# output Progress: 5900 in 13000
# output Progress: 6000 in 13000
# output Progress: 6100 in 13000
# output Progress: 6200 in 13000
# output Progress: 6300 in 13000
# output Progress: 6400 in 13000
# output Progress: 6500 in 13000
# output Progress: 6600 in 13000
# output Progress: 6700 in 13000
# output Progress: 6800 in 13000
# output Progress: 6900 in 13000
# output Progress: 7000 in 13000
# output Progress: 7100 in 13000
# output Progress: 7200 in 13000
# output Progress: 7300 in 13000
# output Progress: 7400 in 13000
# output Progress: 7500 in 13000
# output Progress: 7600 in 13000
# output Progress: 7700 in 13000
# output Progress: 7800 in 13000
# output Progress: 7900 in 13000
# output Progress: 8000 in 13000
# output Progress: 8100 in 13000
# output Progress: 8200 in 13000
# output Progress: 8300 in 13000
# output Progress: 8400 in 13000
# output Progress: 8500 in 13000
# output Progress: 8600 in 13000
# output Progress: 8700 in 13000
# output Progress: 8800 in 13000
# output Progress: 8900 in 13000
# output Progress: 9000 in 13000
# output Progress: 9100 in 13000
# output Progress: 9200 in 13000
# output Progress: 9300 in 13000
# output Progress: 9400 in 13000
# output Progress: 9500 in 13000
# output Progress: 9600 in 13000
# output Progress: 9700 in 13000
# output Progress: 9800 in 13000
# output Progress: 9900 in 13000
# output Progress: 10000 in 13000
# output Progress: 10100 in 13000
# output Progress: 10200 in 13000
# output Progress: 10300 in 13000
# output Progress: 10400 in 13000
# output Progress: 10500 in 13000
# output Progress: 10600 in 13000
# output Progress: 10700 in 13000
# output Progress: 10800 in 13000
# output Progress: 10900 in 13000
# output Progress: 11000 in 13000
# output Progress: 11100 in 13000
# output Progress: 11200 in 13000
# output Progress: 11300 in 13000
# output Progress: 11400 in 13000
# output Progress: 11500 in 13000
# output Progress: 11600 in 13000
# output Progress: 11700 in 13000
# output Progress: 11800 in 13000
# output Progress: 11900 in 13000
# output Progress: 12000 in 13000
# output Progress: 12100 in 13000
# output Progress: 12200 in 13000
# output Progress: 12300 in 13000
# output Progress: 12400 in 13000
# output Progress: 12500 in 13000
# output Progress: 12600 in 13000
# output Progress: 12700 in 13000
# output Progress: 12800 in 13000
# output Progress: 12900 in 13000

# %%
import shutil

# %%
outputs = ['output', 'aug']
i = 0
for output_dir in outputs:
  for filename in os.listdir(output_dir):
    if not filename.endswith('.png') and not filename.endswith('.csv'):
      continue
    if filename == 'embeddings.csv':
      final_filename = f'embeddings{i}.csv'
      i += 1
    else:
      final_filename = filename
    shutil.copy(os.path.join(output_dir, filename), os.path.join('final_output', final_filename))

# %%
import pandas as pd

# List of file paths of CSV files to
dfs = []
for filename in os.listdir('final_output'):
  if not filename.endswith('.csv'):
    continue
  df = pd.read_csv(os.path.join('final_output', filename))
  dfs.append(df)

# Concatenate DataFrames into a single DataFrame
merged_df = pd.concat(dfs, ignore_index=True)

# Write the merged DataFrame to a new CSV file
merged_df.to_csv("final_embeddings.csv", index=False)

# %%
# !zip -r zipped_all.zip ./output/*
# Out:
# Streaming output truncated to the last 5000 lines.
#   adding: output/268786.png (stored 0%)
#   adding: output/268819.png (stored 0%)
#   adding: output/268835.png (stored 0%)
#   adding: output/268851.png (stored 0%)
#   adding: output/268852.png (stored 0%)
#   adding: output/268916.png (stored 0%)
#   adding: output/268919.png (stored 0%)
#   adding: output/268957.png (stored 0%)
#   adding: output/268961.png (stored 0%)
#   adding: output/268965.png (stored 0%)
#   adding: output/268979.png (stored 0%)
#   adding: output/269038.png (stored 0%)
#   adding: output/269060.png (stored 0%)
#   adding: output/269061.png (stored 0%)
#   adding: output/269062.png (stored 0%)
#   adding: output/269149.png (stored 0%)
#   adding: output/269151.png (stored 0%)
#   adding: output/269157.png (stored 0%)
#   adding: output/269196.png (stored 0%)
#   adding: output/269214.png (stored 0%)
#   adding: output/269218.png (stored 0%)
#   adding: output/269229.png (stored 0%)
#   adding: output/269273.png (stored 0%)
#   adding: output/269288.png (stored 0%)
#   adding: output/269323.png (stored 0%)
#   adding: output/269375.png (stored 0%)
#   adding: output/269385.png (stored 0%)
#   adding: output/269501.png (stored 0%)
#   adding: output/269563.png (stored 0%)
#   adding: output/269566.png (stored 0%)
#   adding: output/269593.png (stored 0%)
#   adding: output/269603.png (stored 0%)
#   adding: output/269618.png (stored 0%)
#   adding: output/269619.png (stored 0%)
#   adding: output/269644.png (stored 0%)
#   adding: output/269668.png (stored 0%)
#   adding: output/269672.png (stored 0%)
#   adding: output/269705.png (stored 0%)
#   adding: output/269761.png (stored 0%)
#   adding: output/269762.png (stored 0%)
#   adding: output/269778.png (stored 0%)
#   adding: output/26978.png (stored 0%)
#   adding: output/269807.png (stored 0%)
#   adding: output/269811.png (stored 0%)
#   adding: output/269827.png (stored 0%)
#   adding: output/269832.png (stored 0%)
#   adding: output/269849.png (stored 0%)
#   adding: output/26986.png (stored 0%)
#   adding: output/269882.png (stored 0%)
#   adding: output/269899.png (stored 0%)
#   adding: output/269912.png (stored 0%)
#   adding: output/269927.png (stored 0%)
#   adding: output/269950.png (stored 0%)
#   adding: output/269956.png (stored 0%)
#   adding: output/269991.png (stored 0%)
#   adding: output/270005.png (stored 0%)
#   adding: output/270046.png (stored 0%)
#   adding: output/27005.png (stored 0%)
#   adding: output/270065.png (stored 0%)
#   adding: output/270084.png (stored 0%)
#   adding: output/270085.png (stored 0%)
#   adding: output/270126.png (stored 0%)
#   adding: output/270136.png (stored 0%)
#   adding: output/270147.png (stored 0%)
#   adding: output/270175.png (stored 0%)
#   adding: output/270179.png (stored 0%)
#   adding: output/270185.png (stored 0%)
#   adding: output/270190.png (stored 0%)
#   adding: output/270214.png (stored 0%)
#   adding: output/270217.png (stored 0%)
#   adding: output/27024.png (stored 0%)
#   adding: output/270289.png (stored 0%)
#   adding: output/270299.png (stored 0%)
#   adding: output/270312.png (stored 0%)
#   adding: output/270318.png (stored 0%)
#   adding: output/270341.png (stored 0%)
#   adding: output/27034.png (stored 0%)
#   adding: output/270350.png (stored 0%)
#   adding: output/270402.png (stored 0%)
#   adding: output/270432.png (stored 0%)
#   adding: output/270444.png (stored 0%)
#   adding: output/270448.png (stored 0%)
#   adding: output/270477.png (stored 0%)
#   adding: output/270488.png (stored 0%)
#   adding: output/270543.png (stored 0%)
#   adding: output/270592.png (stored 0%)
#   adding: output/270617.png (stored 0%)
#   adding: output/270620.png (stored 0%)
#   adding: output/270654.png (stored 0%)
#   adding: output/270675.png (stored 0%)
#   adding: output/270687.png (stored 0%)
#   adding: output/270728.png (stored 0%)
#   adding: output/270746.png (stored 0%)
#   adding: output/270752.png (stored 0%)
#   adding: output/270753.png (stored 0%)
#   adding: output/270761.png (stored 0%)
#   adding: output/270764.png (stored 0%)
#   adding: output/270768.png (stored 0%)
#   adding: output/27076.png (deflated 0%)
#   adding: output/270775.png (stored 0%)
#   adding: output/270793.png (stored 0%)
#   adding: output/270796.png (stored 0%)
#   adding: output/270799.png (stored 0%)
#   adding: output/270807.png (stored 0%)
#   adding: output/270811.png (stored 0%)
#   adding: output/270825.png (stored 0%)
#   adding: output/270841.png (stored 0%)
#   adding: output/270857.png (stored 0%)
#   adding: output/270883.png (stored 0%)
#   adding: output/270896.png (stored 0%)
#   adding: output/270940.png (stored 0%)
#   adding: output/270945.png (stored 0%)
#   adding: output/270956.png (stored 0%)
#   adding: output/270963.png (stored 0%)
#   adding: output/270990.png (stored 0%)
#   adding: output/270993.png (stored 0%)
#   adding: output/271006.png (stored 0%)
#   adding: output/271011.png (stored 0%)
#   adding: output/27101.png (stored 0%)
#   adding: output/271034.png (stored 0%)
#   adding: output/27103.png (stored 0%)
#   adding: output/271078.png (stored 0%)
#   adding: output/271081.png (stored 0%)
#   adding: output/271095.png (stored 0%)
#   adding: output/271126.png (stored 0%)
#   adding: output/27112.png (stored 0%)
#   adding: output/271142.png (stored 0%)
#   adding: output/271200.png (stored 0%)
#   adding: output/271202.png (stored 0%)
#   adding: output/271212.png (stored 0%)
#   adding: output/271258.png (stored 0%)
#   adding: output/271303.png (stored 0%)
#   adding: output/271307.png (stored 0%)
#   adding: output/271333.png (stored 0%)
#   adding: output/271410.png (stored 0%)
#   adding: output/271419.png (stored 0%)
#   adding: output/271434.png (stored 0%)
#   adding: output/271453.png (stored 0%)
#   adding: output/271468.png (stored 0%)
#   adding: output/271494.png (stored 0%)
#   adding: output/271508.png (stored 0%)
#   adding: output/271563.png (stored 0%)
#   adding: output/271568.png (stored 0%)
#   adding: output/271614.png (stored 0%)
#   adding: output/271649.png (stored 0%)
#   adding: output/271673.png (stored 0%)
#   adding: output/271696.png (stored 0%)
#   adding: output/271741.png (stored 0%)
#   adding: output/271747.png (stored 0%)
#   adding: output/271767.png (stored 0%)
#   adding: output/271807.png (stored 0%)
#   adding: output/271842.png (stored 0%)
#   adding: output/271901.png (stored 0%)
#   adding: output/271910.png (stored 0%)
#   adding: output/271932.png (stored 0%)
#   adding: output/27193.png (stored 0%)
#   adding: output/271940.png (stored 0%)
#   adding: output/27198.png (stored 0%)
#   adding: output/271995.png (stored 0%)
#   adding: output/272005.png (stored 0%)
#   adding: output/27200.png (stored 0%)
#   adding: output/272044.png (stored 0%)
#   adding: output/272065.png (stored 0%)
#   adding: output/272113.png (stored 0%)
#   adding: output/272155.png (stored 0%)
#   adding: output/272179.png (stored 0%)
#   adding: output/272211.png (stored 0%)
#   adding: output/272232.png (stored 0%)
#   adding: output/272246.png (stored 0%)
#   adding: output/272255.png (stored 0%)
#   adding: output/272278.png (stored 0%)
#   adding: output/27227.png (stored 0%)
#   adding: output/272288.png (stored 0%)
#   adding: output/272323.png (stored 0%)
#   adding: output/272334.png (stored 0%)
#   adding: output/272348.png (stored 0%)
#   adding: output/272364.png (stored 0%)
#   adding: output/272374.png (stored 0%)
#   adding: output/272395.png (stored 0%)
#   adding: output/272401.png (stored 0%)
#   adding: output/272404.png (stored 0%)
#   adding: output/272478.png (stored 0%)
#   adding: output/272483.png (stored 0%)
#   adding: output/272489.png (stored 0%)
#   adding: output/272516.png (stored 0%)
#   adding: output/272538.png (stored 0%)
#   adding: output/272552.png (stored 0%)
#   adding: output/272578.png (stored 0%)
#   adding: output/27258.png (stored 0%)
#   adding: output/272602.png (stored 0%)
#   adding: output/272617.png (stored 0%)
#   adding: output/272623.png (stored 0%)
#   adding: output/272625.png (stored 0%)
#   adding: output/272626.png (stored 0%)
#   adding: output/272669.png (stored 0%)
#   adding: output/27266.png (stored 0%)
#   adding: output/27268.png (stored 0%)
#   adding: output/272696.png (stored 0%)
#   adding: output/272702.png (stored 0%)
#   adding: output/272703.png (stored 0%)
#   adding: output/272719.png (stored 0%)
#   adding: output/272727.png (stored 0%)
#   adding: output/272730.png (stored 0%)
#   adding: output/272738.png (stored 0%)
#   adding: output/272754.png (stored 0%)
#   adding: output/272769.png (stored 0%)
#   adding: output/272775.png (stored 0%)
#   adding: output/272777.png (stored 0%)
#   adding: output/272869.png (stored 0%)
#   adding: output/27286.png (stored 0%)
#   adding: output/272914.png (stored 0%)
#   adding: output/27295.png (stored 0%)
#   adding: output/27297.png (stored 0%)
#   adding: output/273001.png (stored 0%)
#   adding: output/273025.png (stored 0%)
#   adding: output/273055.png (stored 0%)
#   adding: output/27305.png (stored 0%)
#   adding: output/273064.png (stored 0%)
#   adding: output/273119.png (stored 0%)
#   adding: output/273123.png (stored 0%)
#   adding: output/273152.png (stored 0%)
#   adding: output/273181.png (stored 0%)
#   adding: output/273188.png (stored 0%)
#   adding: output/273222.png (stored 0%)
#   adding: output/273251.png (stored 0%)
#   adding: output/27325.png (stored 0%)
#   adding: output/273268.png (stored 0%)
#   adding: output/27328.png (stored 0%)
#   adding: output/273321.png (stored 0%)
#   adding: output/273322.png (stored 0%)
#   adding: output/273365.png (stored 0%)
#   adding: output/273440.png (stored 0%)
#   adding: output/273441.png (stored 0%)
#   adding: output/273450.png (stored 0%)
#   adding: output/273462.png (stored 0%)
#   adding: output/273479.png (stored 0%)
#   adding: output/273491.png (stored 0%)
#   adding: output/273514.png (stored 0%)
#   adding: output/273548.png (stored 0%)
#   adding: output/273563.png (stored 0%)
#   adding: output/273570.png (stored 0%)
#   adding: output/273584.png (stored 0%)
#   adding: output/273621.png (stored 0%)
#   adding: output/273656.png (stored 0%)
#   adding: output/273675.png (stored 0%)
#   adding: output/273706.png (stored 0%)
#   adding: output/273713.png (stored 0%)
#   adding: output/273729.png (stored 0%)
#   adding: output/273792.png (stored 0%)
#   adding: output/273794.png (stored 0%)
#   adding: output/273797.png (stored 0%)
#   adding: output/273876.png (stored 0%)
#   adding: output/273878.png (stored 0%)
#   adding: output/273887.png (stored 0%)
#   adding: output/273919.png (stored 0%)
#   adding: output/273970.png (stored 0%)
#   adding: output/273983.png (stored 0%)
#   adding: output/27400.png (stored 0%)
#   adding: output/274028.png (stored 0%)
#   adding: output/274057.png (stored 0%)
#   adding: output/274064.png (stored 0%)
#   adding: output/274077.png (stored 0%)
#   adding: output/274144.png (stored 0%)
#   adding: output/274159.png (stored 0%)
#   adding: output/274162.png (stored 0%)
#   adding: output/274197.png (stored 0%)
#   adding: output/274209.png (stored 0%)
#   adding: output/27421.png (stored 0%)
#   adding: output/274243.png (stored 0%)
#   adding: output/274250.png (stored 0%)
#   adding: output/274303.png (stored 0%)
#   adding: output/274311.png (stored 0%)
#   adding: output/274319.png (stored 0%)
#   adding: output/274321.png (stored 0%)
#   adding: output/274342.png (stored 0%)
#   adding: output/274371.png (stored 0%)
#   adding: output/274440.png (stored 0%)
#   adding: output/274468.png (stored 0%)
#   adding: output/274494.png (stored 0%)
#   adding: output/274539.png (stored 0%)
#   adding: output/274566.png (stored 0%)
#   adding: output/274575.png (stored 0%)
#   adding: output/274580.png (stored 0%)
#   adding: output/27458.png (stored 0%)
#   adding: output/274602.png (stored 0%)
#   adding: output/27462.png (stored 0%)
#   adding: output/274685.png (stored 0%)
#   adding: output/274687.png (stored 0%)
#   adding: output/274710.png (stored 0%)
#   adding: output/274731.png (stored 0%)
#   adding: output/274761.png (stored 0%)
#   adding: output/274763.png (stored 0%)
#   adding: output/274785.png (stored 0%)
#   adding: output/274786.png (stored 0%)
#   adding: output/274794.png (stored 0%)
#   adding: output/274836.png (stored 0%)
#   adding: output/274848.png (stored 0%)
#   adding: output/274864.png (stored 0%)
#   adding: output/274875.png (stored 0%)
#   adding: output/274890.png (stored 0%)
#   adding: output/274912.png (stored 0%)
#   adding: output/27492.png (stored 0%)
#   adding: output/274934.png (stored 0%)
#   adding: output/274946.png (stored 0%)
#   adding: output/274970.png (stored 0%)
#   adding: output/274978.png (stored 0%)
#   adding: output/275007.png (stored 0%)
#   adding: output/275020.png (stored 0%)
#   adding: output/275049.png (stored 0%)
#   adding: output/275062.png (stored 0%)
#   adding: output/275092.png (stored 0%)
#   adding: output/275133.png (stored 0%)
#   adding: output/275153.png (stored 0%)
#   adding: output/275168.png (stored 0%)
#   adding: output/275189.png (stored 0%)
#   adding: output/275204.png (stored 0%)
#   adding: output/275206.png (stored 0%)
#   adding: output/275220.png (stored 0%)
#   adding: output/275241.png (stored 0%)
#   adding: output/275247.png (stored 0%)
#   adding: output/27529.png (stored 0%)
#   adding: output/275307.png (stored 0%)
#   adding: output/275336.png (stored 0%)
#   adding: output/275346.png (stored 0%)
#   adding: output/275350.png (stored 0%)
#   adding: output/275413.png (stored 0%)
#   adding: output/275436.png (stored 0%)
#   adding: output/275456.png (stored 0%)
#   adding: output/275464.png (stored 0%)
#   adding: output/27547.png (stored 0%)
#   adding: output/275480.png (stored 0%)
#   adding: output/275484.png (stored 0%)
#   adding: output/27548.png (stored 0%)
#   adding: output/275526.png (stored 0%)
#   adding: output/275544.png (stored 0%)
#   adding: output/275615.png (stored 0%)
#   adding: output/275644.png (stored 0%)
#   adding: output/275685.png (stored 0%)
#   adding: output/27568.png (stored 0%)
#   adding: output/275710.png (stored 0%)
#   adding: output/275719.png (stored 0%)
#   adding: output/275729.png (stored 0%)
#   adding: output/275749.png (stored 0%)
#   adding: output/275770.png (stored 0%)
#   adding: output/27586.png (stored 0%)
#   adding: output/275885.png (stored 0%)
#   adding: output/2758.png (stored 0%)
#   adding: output/275905.png (stored 0%)
#   adding: output/275913.png (stored 0%)
#   adding: output/275915.png (stored 0%)
#   adding: output/276032.png (stored 0%)
#   adding: output/276059.png (stored 0%)
#   adding: output/276066.png (stored 0%)
#   adding: output/27606.png (stored 0%)
#   adding: output/276075.png (stored 0%)
#   adding: output/276143.png (stored 0%)
#   adding: output/276156.png (stored 0%)
#   adding: output/276164.png (stored 0%)
#   adding: output/276175.png (stored 0%)
#   adding: output/276192.png (stored 0%)
#   adding: output/276208.png (stored 0%)
#   adding: output/276218.png (stored 0%)
#   adding: output/276232.png (stored 0%)
#   adding: output/276268.png (stored 0%)
#   adding: output/27628.png (stored 0%)
#   adding: output/2762.png (stored 0%)
#   adding: output/276312.png (stored 0%)
#   adding: output/276316.png (stored 0%)
#   adding: output/276322.png (stored 0%)
#   adding: output/276335.png (stored 0%)
#   adding: output/276341.png (stored 0%)
#   adding: output/276367.png (stored 0%)
#   adding: output/27637.png (deflated 1%)
#   adding: output/276408.png (stored 0%)
#   adding: output/276428.png (stored 0%)
#   adding: output/276463.png (stored 0%)
#   adding: output/276465.png (stored 0%)
#   adding: output/276467.png (stored 0%)
#   adding: output/276468.png (stored 0%)
#   adding: output/276481.png (stored 0%)
#   adding: output/276515.png (stored 0%)
#   adding: output/27652.png (stored 0%)
#   adding: output/276532.png (stored 0%)
#   adding: output/276549.png (stored 0%)
#   adding: output/276619.png (stored 0%)
#   adding: output/276630.png (stored 0%)
#   adding: output/27663.png (deflated 0%)
#   adding: output/276669.png (stored 0%)
#   adding: output/276729.png (stored 0%)
#   adding: output/276738.png (stored 0%)
#   adding: output/276787.png (stored 0%)
#   adding: output/276823.png (stored 0%)
#   adding: output/276866.png (stored 0%)
#   adding: output/276877.png (stored 0%)
#   adding: output/276936.png (stored 0%)
#   adding: output/276960.png (stored 0%)
#   adding: output/276979.png (stored 0%)
#   adding: output/276990.png (stored 0%)
#   adding: output/276993.png (stored 0%)
#   adding: output/277010.png (stored 0%)
#   adding: output/277015.png (stored 0%)
#   adding: output/277019.png (stored 0%)
#   adding: output/277039.png (stored 0%)
#   adding: output/27703.png (stored 0%)
#   adding: output/27706.png (stored 0%)
#   adding: output/277116.png (stored 0%)
#   adding: output/277179.png (stored 0%)
#   adding: output/277184.png (stored 0%)
#   adding: output/277191.png (stored 0%)
#   adding: output/277193.png (stored 0%)
#   adding: output/277209.png (stored 0%)
#   adding: output/277215.png (stored 0%)
#   adding: output/277264.png (stored 0%)
#   adding: output/277303.png (stored 0%)
#   adding: output/277329.png (stored 0%)
#   adding: output/27733.png (stored 0%)
#   adding: output/277351.png (stored 0%)
#   adding: output/277354.png (stored 0%)
#   adding: output/277399.png (stored 0%)
#   adding: output/277447.png (stored 0%)
#   adding: output/277510.png (stored 0%)
#   adding: output/277533.png (stored 0%)
#   adding: output/277545.png (stored 0%)
#   adding: output/277556.png (stored 0%)
#   adding: output/277560.png (stored 0%)
#   adding: output/277572.png (stored 0%)
#   adding: output/277582.png (stored 0%)
#   adding: output/277586.png (stored 0%)
#   adding: output/277596.png (stored 0%)
#   adding: output/277600.png (stored 0%)
#   adding: output/277613.png (stored 0%)
#   adding: output/277625.png (stored 0%)
#   adding: output/277632.png (stored 0%)
#   adding: output/27763.png (stored 0%)
#   adding: output/277668.png (stored 0%)
#   adding: output/277702.png (stored 0%)
#   adding: output/27771.png (stored 0%)
#   adding: output/277734.png (stored 0%)
#   adding: output/277752.png (stored 0%)
#   adding: output/277772.png (stored 0%)
#   adding: output/277777.png (stored 0%)
#   adding: output/277843.png (stored 0%)
#   adding: output/277851.png (stored 0%)
#   adding: output/277858.png (stored 0%)
#   adding: output/27788.png (stored 0%)
#   adding: output/277962.png (stored 0%)
#   adding: output/277968.png (stored 0%)
#   adding: output/277980.png (stored 0%)
#   adding: output/277999.png (stored 0%)
#   adding: output/278014.png (stored 0%)
#   adding: output/278018.png (stored 0%)
#   adding: output/278045.png (stored 0%)
#   adding: output/278108.png (stored 0%)
#   adding: output/278172.png (stored 0%)
#   adding: output/278175.png (stored 0%)
#   adding: output/278180.png (stored 0%)
#   adding: output/278183.png (stored 0%)
#   adding: output/2781.png (stored 0%)
#   adding: output/278229.png (stored 0%)
#   adding: output/278254.png (stored 0%)
#   adding: output/278271.png (stored 0%)
#   adding: output/278273.png (stored 0%)
#   adding: output/278280.png (stored 0%)
#   adding: output/278282.png (stored 0%)
#   adding: output/278319.png (stored 0%)
#   adding: output/278327.png (stored 0%)
#   adding: output/278328.png (stored 0%)
#   adding: output/278348.png (stored 0%)
#   adding: output/278358.png (stored 0%)
#   adding: output/278443.png (stored 0%)
#   adding: output/278446.png (stored 0%)
#   adding: output/278454.png (stored 0%)
#   adding: output/278485.png (stored 0%)
#   adding: output/278587.png (stored 0%)
#   adding: output/278618.png (stored 0%)
#   adding: output/278642.png (stored 0%)
#   adding: output/278681.png (stored 0%)
#   adding: output/278682.png (stored 0%)
#   adding: output/278688.png (stored 0%)
#   adding: output/278722.png (stored 0%)
#   adding: output/278728.png (stored 0%)
#   adding: output/278739.png (stored 0%)
#   adding: output/278743.png (stored 0%)
#   adding: output/278778.png (stored 0%)
#   adding: output/278857.png (stored 0%)
#   adding: output/278862.png (stored 0%)
#   adding: output/278875.png (stored 0%)
#   adding: output/278882.png (stored 0%)
#   adding: output/278907.png (stored 0%)
#   adding: output/278956.png (stored 0%)
#   adding: output/279003.png (stored 0%)
#   adding: output/279062.png (stored 0%)
#   adding: output/279078.png (stored 0%)
#   adding: output/27910.png (stored 0%)
#   adding: output/279126.png (stored 0%)
#   adding: output/279145.png (stored 0%)
#   adding: output/279150.png (stored 0%)
#   adding: output/27915.png (stored 0%)
#   adding: output/279175.png (stored 0%)
#   adding: output/279230.png (stored 0%)
#   adding: output/279244.png (stored 0%)
#   adding: output/279322.png (stored 0%)
#   adding: output/279328.png (stored 0%)
#   adding: output/279461.png (stored 0%)
#   adding: output/279469.png (stored 0%)
#   adding: output/279471.png (stored 0%)
#   adding: output/279504.png (stored 0%)
#   adding: output/27955.png (stored 0%)
#   adding: output/279563.png (stored 0%)
#   adding: output/279572.png (stored 0%)
#   adding: output/279600.png (stored 0%)
#   adding: output/279614.png (stored 0%)
#   adding: output/279679.png (stored 0%)
#   adding: output/279700.png (stored 0%)
#   adding: output/279707.png (stored 0%)
#   adding: output/279717.png (stored 0%)
#   adding: output/27972.png (stored 0%)
#   adding: output/279745.png (stored 0%)
#   adding: output/27974.png (stored 0%)
#   adding: output/279751.png (stored 0%)
#   adding: output/279756.png (stored 0%)
#   adding: output/27978.png (deflated 1%)
#   adding: output/279824.png (stored 0%)
#   adding: output/279837.png (stored 0%)
#   adding: output/27983.png (stored 0%)
#   adding: output/279914.png (stored 0%)
#   adding: output/279947.png (stored 0%)
#   adding: output/279999.png (stored 0%)
#   adding: output/27.png (stored 0%)
#   adding: output/280023.png (stored 0%)
#   adding: output/280024.png (stored 0%)
#   adding: output/280058.png (stored 0%)
#   adding: output/28009.png (stored 0%)
#   adding: output/280108.png (stored 0%)
#   adding: output/280111.png (stored 0%)
#   adding: output/280117.png (stored 0%)
#   adding: output/280119.png (stored 0%)
#   adding: output/280149.png (stored 0%)
#   adding: output/280180.png (stored 0%)
#   adding: output/280232.png (stored 0%)
#   adding: output/280245.png (stored 0%)
#   adding: output/280259.png (stored 0%)
#   adding: output/280264.png (stored 0%)
#   adding: output/280269.png (stored 0%)
#   adding: output/280335.png (stored 0%)
#   adding: output/280363.png (stored 0%)
#   adding: output/280389.png (stored 0%)
#   adding: output/280405.png (stored 0%)
#   adding: output/28040.png (stored 0%)
#   adding: output/280451.png (stored 0%)
#   adding: output/28046.png (stored 0%)
#   adding: output/280491.png (stored 0%)
#   adding: output/280530.png (stored 0%)
#   adding: output/280532.png (stored 0%)
#   adding: output/280552.png (stored 0%)
#   adding: output/280582.png (stored 0%)
#   adding: output/280592.png (stored 0%)
#   adding: output/280600.png (stored 0%)
#   adding: output/280619.png (stored 0%)
#   adding: output/280621.png (stored 0%)
#   adding: output/280628.png (stored 0%)
#   adding: output/280690.png (stored 0%)
#   adding: output/280771.png (stored 0%)
#   adding: output/280803.png (stored 0%)
#   adding: output/280804.png (stored 0%)
#   adding: output/280805.png (stored 0%)
#   adding: output/280827.png (stored 0%)
#   adding: output/280872.png (stored 0%)
#   adding: output/280876.png (stored 0%)
#   adding: output/280885.png (stored 0%)
#   adding: output/280915.png (stored 0%)
#   adding: output/280948.png (stored 0%)
#   adding: output/280965.png (stored 0%)
#   adding: output/280995.png (stored 0%)
#   adding: output/281019.png (stored 0%)
#   adding: output/281024.png (stored 0%)
#   adding: output/281037.png (stored 0%)
#   adding: output/281046.png (stored 0%)
#   adding: output/28105.png (stored 0%)
#   adding: output/28107.png (stored 0%)
#   adding: output/281083.png (stored 0%)
#   adding: output/281136.png (stored 0%)
#   adding: output/281148.png (stored 0%)
#   adding: output/281177.png (stored 0%)
#   adding: output/281195.png (stored 0%)
#   adding: output/281208.png (stored 0%)
#   adding: output/281215.png (stored 0%)
#   adding: output/281243.png (stored 0%)
#   adding: output/281282.png (stored 0%)
#   adding: output/281285.png (stored 0%)
#   adding: output/281296.png (stored 0%)
#   adding: output/281324.png (stored 0%)
#   adding: output/281352.png (stored 0%)
#   adding: output/281361.png (stored 0%)
#   adding: output/281362.png (stored 0%)
#   adding: output/281375.png (stored 0%)
#   adding: output/281389.png (stored 0%)
#   adding: output/281485.png (stored 0%)
#   adding: output/281511.png (stored 0%)
#   adding: output/28151.png (stored 0%)
#   adding: output/281538.png (stored 0%)
#   adding: output/281542.png (stored 0%)
#   adding: output/281551.png (stored 0%)
#   adding: output/281588.png (stored 0%)
#   adding: output/281649.png (stored 0%)
#   adding: output/281673.png (stored 0%)
#   adding: output/281692.png (stored 0%)
#   adding: output/281738.png (stored 0%)
#   adding: output/281782.png (stored 0%)
#   adding: output/281793.png (stored 0%)
#   adding: output/281798.png (stored 0%)
#   adding: output/2817.png (stored 0%)
#   adding: output/281800.png (stored 0%)
#   adding: output/281814.png (stored 0%)
#   adding: output/281828.png (stored 0%)
#   adding: output/281845.png (stored 0%)
#   adding: output/281854.png (stored 0%)
#   adding: output/281857.png (stored 0%)
#   adding: output/281866.png (stored 0%)
#   adding: output/281867.png (stored 0%)
#   adding: output/281883.png (stored 0%)
#   adding: output/28189.png (stored 0%)
#   adding: output/281927.png (stored 0%)
#   adding: output/281934.png (stored 0%)
#   adding: output/281946.png (stored 0%)
#   adding: output/28199.png (stored 0%)
#   adding: output/282058.png (stored 0%)
#   adding: output/28205.png (stored 0%)
#   adding: output/282060.png (stored 0%)
#   adding: output/282071.png (stored 0%)
#   adding: output/282073.png (stored 0%)
#   adding: output/282074.png (stored 0%)
#   adding: output/28208.png (stored 0%)
#   adding: output/282090.png (stored 0%)
#   adding: output/28211.png (stored 0%)
#   adding: output/282134.png (stored 0%)
#   adding: output/282176.png (stored 0%)
#   adding: output/28217.png (stored 0%)
#   adding: output/282189.png (stored 0%)
#   adding: output/28218.png (stored 0%)
#   adding: output/282208.png (stored 0%)
#   adding: output/282210.png (stored 0%)
#   adding: output/282226.png (stored 0%)
#   adding: output/282301.png (stored 0%)
#   adding: output/282303.png (stored 0%)
#   adding: output/282337.png (stored 0%)
#   adding: output/282343.png (stored 0%)
#   adding: output/282344.png (stored 0%)
#   adding: output/282369.png (stored 0%)
#   adding: output/282389.png (stored 0%)
#   adding: output/282391.png (stored 0%)
#   adding: output/282413.png (stored 0%)
#   adding: output/282428.png (stored 0%)
#   adding: output/282429.png (stored 0%)
#   adding: output/282456.png (stored 0%)
#   adding: output/282476.png (stored 0%)
#   adding: output/282502.png (stored 0%)
#   adding: output/282541.png (stored 0%)
#   adding: output/282548.png (stored 0%)
#   adding: output/28254.png (stored 0%)
#   adding: output/282569.png (stored 0%)
#   adding: output/282590.png (stored 0%)
#   adding: output/282613.png (stored 0%)
#   adding: output/282628.png (stored 0%)
#   adding: output/282638.png (stored 0%)
#   adding: output/282646.png (stored 0%)
#   adding: output/282661.png (stored 0%)
#   adding: output/282678.png (stored 0%)
#   adding: output/282691.png (stored 0%)
#   adding: output/282693.png (stored 0%)
#   adding: output/282729.png (stored 0%)
#   adding: output/282757.png (stored 0%)
#   adding: output/282759.png (stored 0%)
#   adding: output/28276.png (stored 0%)
#   adding: output/282808.png (stored 0%)
#   adding: output/282835.png (stored 0%)
#   adding: output/282899.png (stored 0%)
#   adding: output/282907.png (stored 0%)
#   adding: output/282945.png (stored 0%)
#   adding: output/283033.png (stored 0%)
#   adding: output/283047.png (stored 0%)
#   adding: output/283060.png (stored 0%)
#   adding: output/283061.png (stored 0%)
#   adding: output/283066.png (stored 0%)
#   adding: output/28306.png (stored 0%)
#   adding: output/283099.png (stored 0%)
#   adding: output/283100.png (stored 0%)
#   adding: output/283139.png (stored 0%)
#   adding: output/28314.png (stored 0%)
#   adding: output/283187.png (stored 0%)
#   adding: output/283209.png (stored 0%)
#   adding: output/28321.png (stored 0%)
#   adding: output/283259.png (stored 0%)
#   adding: output/283336.png (stored 0%)
#   adding: output/283347.png (stored 0%)
#   adding: output/283380.png (stored 0%)
#   adding: output/283413.png (stored 0%)
#   adding: output/283447.png (stored 0%)
#   adding: output/283468.png (stored 0%)
#   adding: output/283477.png (stored 0%)
#   adding: output/283482.png (stored 0%)
#   adding: output/283498.png (stored 0%)
#   adding: output/283505.png (stored 0%)
#   adding: output/283531.png (stored 0%)
#   adding: output/283596.png (stored 0%)
#   adding: output/283629.png (stored 0%)
#   adding: output/283662.png (stored 0%)
#   adding: output/283666.png (stored 0%)
#   adding: output/28367.png (stored 0%)
#   adding: output/28369.png (deflated 1%)
#   adding: output/283710.png (stored 0%)
#   adding: output/283746.png (stored 0%)
#   adding: output/283777.png (stored 0%)
#   adding: output/283793.png (stored 0%)
#   adding: output/283808.png (stored 0%)
#   adding: output/283809.png (stored 0%)
#   adding: output/283844.png (stored 0%)
#   adding: output/283847.png (stored 0%)
#   adding: output/283850.png (stored 0%)
#   adding: output/283857.png (stored 0%)
#   adding: output/283873.png (stored 0%)
#   adding: output/283972.png (stored 0%)
#   adding: output/283985.png (stored 0%)
#   adding: output/284022.png (stored 0%)
#   adding: output/284128.png (stored 0%)
#   adding: output/284155.png (stored 0%)
#   adding: output/284170.png (stored 0%)
#   adding: output/284180.png (stored 0%)
#   adding: output/284186.png (stored 0%)
#   adding: output/284207.png (stored 0%)
#   adding: output/284280.png (stored 0%)
#   adding: output/284282.png (stored 0%)
#   adding: output/284296.png (stored 0%)
#   adding: output/284309.png (stored 0%)
#   adding: output/284351.png (stored 0%)
#   adding: output/28436.png (stored 0%)
#   adding: output/28437.png (stored 0%)
#   adding: output/284389.png (stored 0%)
#   adding: output/284413.png (stored 0%)
#   adding: output/284421.png (stored 0%)
#   adding: output/284439.png (stored 0%)
#   adding: output/284447.png (stored 0%)
#   adding: output/284475.png (stored 0%)
#   adding: output/284483.png (stored 0%)
#   adding: output/284498.png (stored 0%)
#   adding: output/284525.png (stored 0%)
#   adding: output/284537.png (stored 0%)
#   adding: output/28455.png (stored 0%)
#   adding: output/284579.png (stored 0%)
#   adding: output/284644.png (stored 0%)
#   adding: output/284688.png (stored 0%)
#   adding: output/284690.png (stored 0%)
#   adding: output/284737.png (stored 0%)
#   adding: output/284754.png (stored 0%)
#   adding: output/284768.png (stored 0%)
#   adding: output/284775.png (stored 0%)
#   adding: output/284776.png (stored 0%)
#   adding: output/284788.png (stored 0%)
#   adding: output/284840.png (stored 0%)
#   adding: output/284924.png (stored 0%)
#   adding: output/285019.png (stored 0%)
#   adding: output/285031.png (stored 0%)
#   adding: output/285062.png (stored 0%)
#   adding: output/285074.png (stored 0%)
#   adding: output/285086.png (stored 0%)
#   adding: output/285109.png (stored 0%)
#   adding: output/285113.png (stored 0%)
#   adding: output/285191.png (stored 0%)
#   adding: output/285203.png (stored 0%)
#   adding: output/285217.png (stored 0%)
#   adding: output/285315.png (stored 0%)
#   adding: output/285327.png (stored 0%)
#   adding: output/285339.png (stored 0%)
#   adding: output/285361.png (stored 0%)
#   adding: output/285363.png (stored 0%)
#   adding: output/285366.png (stored 0%)
#   adding: output/285374.png (stored 0%)
#   adding: output/285391.png (stored 0%)
#   adding: output/285436.png (stored 0%)
#   adding: output/285488.png (stored 0%)
#   adding: output/285548.png (stored 0%)
#   adding: output/285596.png (stored 0%)
#   adding: output/285605.png (stored 0%)
#   adding: output/28561.png (stored 0%)
#   adding: output/28563.png (stored 0%)
#   adding: output/285651.png (stored 0%)
#   adding: output/285672.png (stored 0%)
#   adding: output/285676.png (stored 0%)
#   adding: output/285829.png (stored 0%)
#   adding: output/285845.png (stored 0%)
#   adding: output/285861.png (stored 0%)
#   adding: output/285863.png (stored 0%)
#   adding: output/285914.png (stored 0%)
#   adding: output/285959.png (stored 0%)
#   adding: output/28598.png (deflated 0%)
#   adding: output/285995.png (stored 0%)
#   adding: output/286007.png (stored 0%)
#   adding: output/286008.png (stored 0%)
#   adding: output/286061.png (stored 0%)
#   adding: output/286075.png (stored 0%)
#   adding: output/286089.png (stored 0%)
#   adding: output/286095.png (stored 0%)
#   adding: output/286106.png (stored 0%)
#   adding: output/286115.png (stored 0%)
#   adding: output/286123.png (stored 0%)
#   adding: output/286129.png (stored 0%)
#   adding: output/286156.png (stored 0%)
#   adding: output/286164.png (stored 0%)
#   adding: output/286221.png (stored 0%)
#   adding: output/286227.png (stored 0%)
#   adding: output/28624.png (stored 0%)
#   adding: output/286336.png (stored 0%)
#   adding: output/286338.png (stored 0%)
#   adding: output/286347.png (stored 0%)
#   adding: output/28634.png (stored 0%)
#   adding: output/286357.png (stored 0%)
#   adding: output/286368.png (stored 0%)
#   adding: output/286381.png (stored 0%)
#   adding: output/286463.png (stored 0%)
#   adding: output/286466.png (stored 0%)
#   adding: output/286501.png (stored 0%)
#   adding: output/286514.png (stored 0%)
#   adding: output/286525.png (stored 0%)
#   adding: output/286536.png (stored 0%)
#   adding: output/286545.png (stored 0%)
#   adding: output/286613.png (stored 0%)
#   adding: output/286637.png (stored 0%)
#   adding: output/286640.png (stored 0%)
#   adding: output/286646.png (stored 0%)
#   adding: output/286666.png (stored 0%)
#   adding: output/286686.png (stored 0%)
#   adding: output/286714.png (stored 0%)
#   adding: output/286725.png (stored 0%)
#   adding: output/286729.png (stored 0%)
#   adding: output/286766.png (stored 0%)
#   adding: output/28678.png (stored 0%)
#   adding: output/286805.png (stored 0%)
#   adding: output/286829.png (stored 0%)
#   adding: output/28685.png (stored 0%)
#   adding: output/286868.png (stored 0%)
#   adding: output/286875.png (stored 0%)
#   adding: output/286886.png (stored 0%)
#   adding: output/286906.png (stored 0%)
#   adding: output/287061.png (stored 0%)
#   adding: output/28710.png (stored 0%)
#   adding: output/287127.png (stored 0%)
#   adding: output/287151.png (stored 0%)
#   adding: output/287166.png (stored 0%)
#   adding: output/287198.png (stored 0%)
#   adding: output/2871.png (stored 0%)
#   adding: output/287208.png (stored 0%)
#   adding: output/287257.png (stored 0%)
#   adding: output/287259.png (stored 0%)
#   adding: output/287335.png (stored 0%)
#   adding: output/287353.png (stored 0%)
#   adding: output/287370.png (stored 0%)
#   adding: output/287400.png (stored 0%)
#   adding: output/287411.png (stored 0%)
#   adding: output/287415.png (stored 0%)
#   adding: output/287419.png (stored 0%)
#   adding: output/287456.png (stored 0%)
#   adding: output/287479.png (stored 0%)
#   adding: output/287523.png (stored 0%)
#   adding: output/287537.png (stored 0%)
#   adding: output/287550.png (stored 0%)
#   adding: output/287584.png (stored 0%)
#   adding: output/287600.png (stored 0%)
#   adding: output/28765.png (stored 0%)
#   adding: output/287684.png (stored 0%)
#   adding: output/28769.png (stored 0%)
#   adding: output/287727.png (stored 0%)
#   adding: output/287768.png (stored 0%)
#   adding: output/28778.png (stored 0%)
#   adding: output/287805.png (stored 0%)
#   adding: output/287814.png (stored 0%)
#   adding: output/287846.png (stored 0%)
#   adding: output/287865.png (stored 0%)
#   adding: output/287889.png (stored 0%)
#   adding: output/287893.png (stored 0%)
#   adding: output/287894.png (stored 0%)
#   adding: output/287901.png (stored 0%)
#   adding: output/287909.png (stored 0%)
#   adding: output/287931.png (stored 0%)
#   adding: output/287940.png (stored 0%)
#   adding: output/287983.png (stored 0%)
#   adding: output/28798.png (stored 0%)
#   adding: output/287997.png (stored 0%)
#   adding: output/288014.png (stored 0%)
#   adding: output/288017.png (stored 0%)
#   adding: output/288038.png (stored 0%)
#   adding: output/288087.png (stored 0%)
#   adding: output/288112.png (stored 0%)
#   adding: output/288145.png (stored 0%)
#   adding: output/288150.png (stored 0%)
#   adding: output/28815.png (stored 0%)
#   adding: output/288205.png (stored 0%)
#   adding: output/288240.png (stored 0%)
#   adding: output/288244.png (stored 0%)
#   adding: output/288313.png (stored 0%)
#   adding: output/288324.png (stored 0%)
#   adding: output/288328.png (stored 0%)
#   adding: output/288333.png (stored 0%)
#   adding: output/288353.png (stored 0%)
#   adding: output/288379.png (stored 0%)
#   adding: output/288406.png (stored 0%)
#   adding: output/288419.png (stored 0%)
#   adding: output/288425.png (stored 0%)
#   adding: output/288442.png (stored 0%)
#   adding: output/288484.png (stored 0%)
#   adding: output/288490.png (stored 0%)
#   adding: output/288508.png (stored 0%)
#   adding: output/288513.png (stored 0%)
#   adding: output/288552.png (stored 0%)
#   adding: output/288557.png (stored 0%)
#   adding: output/288565.png (stored 0%)
#   adding: output/288570.png (stored 0%)
#   adding: output/288583.png (stored 0%)
#   adding: output/288593.png (stored 0%)
#   adding: output/288599.png (stored 0%)
#   adding: output/288603.png (stored 0%)
#   adding: output/288613.png (stored 0%)
#   adding: output/288666.png (stored 0%)
#   adding: output/28869.png (stored 0%)
#   adding: output/288728.png (stored 0%)
#   adding: output/288733.png (stored 0%)
#   adding: output/28874.png (stored 0%)
#   adding: output/288750.png (stored 0%)
#   adding: output/288761.png (stored 0%)
#   adding: output/288781.png (stored 0%)
#   adding: output/288790.png (stored 0%)
#   adding: output/288815.png (stored 0%)
#   adding: output/28881.png (deflated 1%)
#   adding: output/288821.png (stored 0%)
#   adding: output/288834.png (stored 0%)
#   adding: output/288863.png (stored 0%)
#   adding: output/28888.png (stored 0%)
#   adding: output/288911.png (stored 0%)
#   adding: output/288928.png (stored 0%)
#   adding: output/288935.png (stored 0%)
#   adding: output/288989.png (stored 0%)
#   adding: output/289004.png (stored 0%)
#   adding: output/289042.png (stored 0%)
#   adding: output/289071.png (stored 0%)
#   adding: output/289109.png (stored 0%)
#   adding: output/28910.png (stored 0%)
#   adding: output/289157.png (stored 0%)
#   adding: output/289197.png (stored 0%)
#   adding: output/28919.png (stored 0%)
#   adding: output/28921.png (stored 0%)
#   adding: output/289266.png (stored 0%)
#   adding: output/289280.png (stored 0%)
#   adding: output/289288.png (stored 0%)
#   adding: output/289295.png (stored 0%)
#   adding: output/28929.png (stored 0%)
#   adding: output/289309.png (stored 0%)
#   adding: output/289337.png (stored 0%)
#   adding: output/289352.png (stored 0%)
#   adding: output/289397.png (stored 0%)
#   adding: output/289464.png (stored 0%)
#   adding: output/289466.png (stored 0%)
#   adding: output/289580.png (stored 0%)
#   adding: output/289601.png (stored 0%)
#   adding: output/289617.png (stored 0%)
#   adding: output/289647.png (stored 0%)
#   adding: output/289655.png (stored 0%)
#   adding: output/289721.png (stored 0%)
#   adding: output/289735.png (stored 0%)
#   adding: output/289738.png (stored 0%)
#   adding: output/289774.png (stored 0%)
#   adding: output/28978.png (stored 0%)
#   adding: output/289825.png (stored 0%)
#   adding: output/289827.png (stored 0%)
#   adding: output/28982.png (deflated 1%)
#   adding: output/28985.png (stored 0%)
#   adding: output/289866.png (stored 0%)
#   adding: output/289869.png (stored 0%)
#   adding: output/289904.png (stored 0%)
#   adding: output/289917.png (stored 0%)
#   adding: output/289970.png (stored 0%)
#   adding: output/290014.png (stored 0%)
#   adding: output/29001.png (stored 0%)
#   adding: output/290024.png (stored 0%)
#   adding: output/290025.png (stored 0%)
#   adding: output/29013.png (stored 0%)
#   adding: output/290145.png (stored 0%)
#   adding: output/290179.png (stored 0%)
#   adding: output/290219.png (stored 0%)
#   adding: output/290258.png (stored 0%)
#   adding: output/290320.png (stored 0%)
#   adding: output/290323.png (stored 0%)
#   adding: output/290340.png (stored 0%)
#   adding: output/29036.png (stored 0%)
#   adding: output/29038.png (stored 0%)
#   adding: output/290411.png (stored 0%)
#   adding: output/290485.png (stored 0%)
#   adding: output/290488.png (stored 0%)
#   adding: output/290496.png (stored 0%)
#   adding: output/290508.png (stored 0%)
#   adding: output/290526.png (stored 0%)
#   adding: output/290553.png (stored 0%)
#   adding: output/290557.png (stored 0%)
#   adding: output/290560.png (stored 0%)
#   adding: output/290563.png (stored 0%)
#   adding: output/290591.png (stored 0%)
#   adding: output/290606.png (stored 0%)
#   adding: output/290620.png (stored 0%)
#   adding: output/290624.png (stored 0%)
#   adding: output/29062.png (deflated 1%)
#   adding: output/290651.png (stored 0%)
#   adding: output/290656.png (stored 0%)
#   adding: output/290671.png (stored 0%)
#   adding: output/290673.png (stored 0%)
#   adding: output/290690.png (stored 0%)
#   adding: output/290696.png (stored 0%)
#   adding: output/290714.png (stored 0%)
#   adding: output/290720.png (stored 0%)
#   adding: output/290729.png (stored 0%)
#   adding: output/290758.png (stored 0%)
#   adding: output/290763.png (stored 0%)
#   adding: output/290774.png (stored 0%)
#   adding: output/290776.png (stored 0%)
#   adding: output/290783.png (stored 0%)
#   adding: output/290799.png (stored 0%)
#   adding: output/290822.png (stored 0%)
#   adding: output/290922.png (stored 0%)
#   adding: output/29094.png (stored 0%)
#   adding: output/290953.png (stored 0%)
#   adding: output/291012.png (stored 0%)
#   adding: output/291034.png (stored 0%)
#   adding: output/291037.png (stored 0%)
#   adding: output/291047.png (stored 0%)
#   adding: output/291133.png (stored 0%)
#   adding: output/291192.png (stored 0%)
#   adding: output/29120.png (stored 0%)
#   adding: output/291240.png (stored 0%)
#   adding: output/291243.png (stored 0%)
#   adding: output/29124.png (deflated 0%)
#   adding: output/291253.png (stored 0%)
#   adding: output/291278.png (stored 0%)
#   adding: output/291284.png (stored 0%)
#   adding: output/291285.png (stored 0%)
#   adding: output/291381.png (stored 0%)
#   adding: output/291403.png (stored 0%)
#   adding: output/291431.png (stored 0%)
#   adding: output/291450.png (stored 0%)
#   adding: output/291465.png (stored 0%)
#   adding: output/29146.png (stored 0%)
#   adding: output/291476.png (stored 0%)
#   adding: output/291531.png (stored 0%)
#   adding: output/291568.png (stored 0%)
#   adding: output/291589.png (stored 0%)
#   adding: output/291621.png (stored 0%)
#   adding: output/291656.png (stored 0%)
#   adding: output/291670.png (stored 0%)
#   adding: output/291675.png (stored 0%)
#   adding: output/291683.png (stored 0%)
#   adding: output/291686.png (stored 0%)
#   adding: output/291696.png (stored 0%)
#   adding: output/291699.png (stored 0%)
#   adding: output/29172.png (stored 0%)
#   adding: output/291750.png (stored 0%)
#   adding: output/291758.png (stored 0%)
#   adding: output/291763.png (stored 0%)
#   adding: output/291774.png (stored 0%)
#   adding: output/291819.png (stored 0%)
#   adding: output/291830.png (stored 0%)
#   adding: output/291831.png (stored 0%)
#   adding: output/291867.png (stored 0%)
#   adding: output/291893.png (stored 0%)
#   adding: output/291934.png (stored 0%)
#   adding: output/291945.png (stored 0%)
#   adding: output/291949.png (stored 0%)
#   adding: output/292010.png (stored 0%)
#   adding: output/292024.png (stored 0%)
#   adding: output/292025.png (stored 0%)
#   adding: output/292069.png (stored 0%)
#   adding: output/292139.png (stored 0%)
#   adding: output/292152.png (stored 0%)
#   adding: output/292187.png (stored 0%)
#   adding: output/292212.png (stored 0%)
#   adding: output/292220.png (stored 0%)
#   adding: output/292227.png (stored 0%)
#   adding: output/292228.png (stored 0%)
#   adding: output/292230.png (stored 0%)
#   adding: output/292256.png (stored 0%)
#   adding: output/292289.png (stored 0%)
#   adding: output/292295.png (stored 0%)
#   adding: output/29231.png (stored 0%)
#   adding: output/292336.png (stored 0%)
#   adding: output/29236.png (stored 0%)
#   adding: output/292416.png (stored 0%)
#   adding: output/292430.png (stored 0%)
#   adding: output/292450.png (stored 0%)
#   adding: output/292480.png (stored 0%)
#   adding: output/292486.png (stored 0%)
#   adding: output/292520.png (stored 0%)
#   adding: output/292526.png (stored 0%)
#   adding: output/292535.png (stored 0%)
#   adding: output/29253.png (stored 0%)
#   adding: output/292600.png (stored 0%)
#   adding: output/292654.png (stored 0%)
#   adding: output/292743.png (stored 0%)
#   adding: output/292746.png (stored 0%)
#   adding: output/292747.png (stored 0%)
#   adding: output/292787.png (stored 0%)
#   adding: output/292811.png (stored 0%)
#   adding: output/292812.png (stored 0%)
#   adding: output/292844.png (stored 0%)
#   adding: output/292850.png (stored 0%)
#   adding: output/292871.png (stored 0%)
#   adding: output/292878.png (stored 0%)
#   adding: output/292889.png (stored 0%)
#   adding: output/292890.png (stored 0%)
#   adding: output/292892.png (stored 0%)
#   adding: output/292894.png (stored 0%)
#   adding: output/292896.png (stored 0%)
#   adding: output/292902.png (stored 0%)
#   adding: output/29291.png (stored 0%)
#   adding: output/292962.png (stored 0%)
#   adding: output/293008.png (stored 0%)
#   adding: output/293047.png (stored 0%)
#   adding: output/293048.png (stored 0%)
#   adding: output/293088.png (stored 0%)
#   adding: output/293130.png (stored 0%)
#   adding: output/293138.png (stored 0%)
#   adding: output/293155.png (stored 0%)
#   adding: output/293174.png (stored 0%)
#   adding: output/293196.png (stored 0%)
#   adding: output/293201.png (stored 0%)
#   adding: output/29321.png (stored 0%)
#   adding: output/293228.png (stored 0%)
#   adding: output/293243.png (stored 0%)
#   adding: output/293274.png (stored 0%)
#   adding: output/293291.png (stored 0%)
#   adding: output/293294.png (stored 0%)
#   adding: output/293300.png (stored 0%)
#   adding: output/293310.png (stored 0%)
#   adding: output/293312.png (stored 0%)
#   adding: output/293328.png (stored 0%)
#   adding: output/293366.png (stored 0%)
#   adding: output/29340.png (stored 0%)
#   adding: output/293469.png (stored 0%)
#   adding: output/293510.png (stored 0%)
#   adding: output/293566.png (stored 0%)
#   adding: output/293571.png (stored 0%)
#   adding: output/293572.png (stored 0%)
#   adding: output/293578.png (stored 0%)
#   adding: output/293680.png (stored 0%)
#   adding: output/293689.png (stored 0%)
#   adding: output/293766.png (stored 0%)
#   adding: output/293819.png (stored 0%)
#   adding: output/293907.png (stored 0%)
#   adding: output/294003.png (stored 0%)
#   adding: output/294007.png (stored 0%)
#   adding: output/294022.png (stored 0%)
#   adding: output/294028.png (stored 0%)
#   adding: output/29403.png (stored 0%)
#   adding: output/294055.png (stored 0%)
#   adding: output/294075.png (stored 0%)
#   adding: output/294094.png (stored 0%)
#   adding: output/294100.png (stored 0%)
#   adding: output/294110.png (stored 0%)
#   adding: output/294133.png (stored 0%)
#   adding: output/294205.png (stored 0%)
#   adding: output/294217.png (stored 0%)
#   adding: output/294225.png (stored 0%)
#   adding: output/294237.png (stored 0%)
#   adding: output/294268.png (stored 0%)
#   adding: output/294277.png (stored 0%)
#   adding: output/294282.png (stored 0%)
#   adding: output/294347.png (stored 0%)
#   adding: output/294464.png (stored 0%)
#   adding: output/294482.png (stored 0%)
#   adding: output/294523.png (stored 0%)
#   adding: output/294559.png (stored 0%)
#   adding: output/294596.png (stored 0%)
#   adding: output/294599.png (stored 0%)
#   adding: output/294602.png (stored 0%)
#   adding: output/294653.png (stored 0%)
#   adding: output/294667.png (stored 0%)
#   adding: output/294686.png (stored 0%)
#   adding: output/294688.png (stored 0%)
#   adding: output/294689.png (stored 0%)
#   adding: output/294711.png (stored 0%)
#   adding: output/294716.png (stored 0%)
#   adding: output/294724.png (stored 0%)
#   adding: output/294730.png (stored 0%)
#   adding: output/294821.png (stored 0%)
#   adding: output/294823.png (stored 0%)
#   adding: output/29486.png (stored 0%)
#   adding: output/294877.png (stored 0%)
#   adding: output/294887.png (stored 0%)
#   adding: output/294891.png (stored 0%)
#   adding: output/294919.png (stored 0%)
#   adding: output/294920.png (stored 0%)
#   adding: output/294937.png (stored 0%)
#   adding: output/294966.png (stored 0%)
#   adding: output/294972.png (stored 0%)
#   adding: output/294990.png (stored 0%)
#   adding: output/294995.png (stored 0%)
#   adding: output/29499.png (stored 0%)
# ...
#   adding: output/90709.png (stored 0%)
#   adding: output/90725.png (stored 0%)
#   adding: output/90726.png (stored 0%)
#   adding: output/90749.png (stored 0%)
#   adding: output/9079.png (stored 0%)
#   adding: output/90811.png (stored 0%)
#   adding: output/90847.png (stored 0%)
#   adding: output/90864.png (stored 0%)
#   adding: output/90876.png (stored 0%)
#   adding: output/90877.png (stored 0%)
#   adding: output/90903.png (stored 0%)
#   adding: output/90950.png (stored 0%)
#   adding: output/90982.png (stored 0%)
#   adding: output/91002.png (stored 0%)
#   adding: output/91005.png (stored 0%)
#   adding: output/91013.png (stored 0%)
#   adding: output/91014.png (stored 0%)
#   adding: output/91031.png (stored 0%)
#   adding: output/91033.png (stored 0%)
#   adding: output/91035.png (stored 0%)
#   adding: output/91094.png (stored 0%)
#   adding: output/91096.png (stored 0%)
#   adding: output/91098.png (stored 0%)
#   adding: output/9109.png (stored 0%)
#   adding: output/9112.png (stored 0%)
#   adding: output/91151.png (stored 0%)
#   adding: output/91153.png (stored 0%)
#   adding: output/91186.png (stored 0%)
#   adding: output/91240.png (stored 0%)
#   adding: output/91258.png (stored 0%)
#   adding: output/9125.png (stored 0%)
#   adding: output/91265.png (stored 0%)
#   adding: output/91305.png (stored 0%)
#   adding: output/91311.png (stored 0%)
#   adding: output/9133.png (stored 0%)
#   adding: output/91344.png (stored 0%)
#   adding: output/91347.png (stored 0%)
#   adding: output/91369.png (stored 0%)
#   adding: output/9136.png (stored 0%)
#   adding: output/91374.png (stored 0%)
#   adding: output/91428.png (stored 0%)
#   adding: output/91463.png (stored 0%)
#   adding: output/91512.png (stored 0%)
#   adding: output/91549.png (stored 0%)
#   adding: output/91595.png (stored 0%)
#   adding: output/91643.png (stored 0%)
#   adding: output/91644.png (stored 0%)
#   adding: output/91651.png (stored 0%)
#   adding: output/91660.png (stored 0%)
#   adding: output/91717.png (stored 0%)
#   adding: output/91728.png (stored 0%)
#   adding: output/91735.png (stored 0%)
#   adding: output/91737.png (stored 0%)
#   adding: output/91806.png (stored 0%)
#   adding: output/91827.png (stored 0%)
#   adding: output/91830.png (stored 0%)
#   adding: output/91834.png (stored 0%)
#   adding: output/91839.png (stored 0%)
#   adding: output/9188.png (stored 0%)
#   adding: output/91941.png (stored 0%)
#   adding: output/9194.png (stored 0%)
#   adding: output/91958.png (stored 0%)
#   adding: output/91999.png (stored 0%)
#   adding: output/92031.png (stored 0%)
#   adding: output/92042.png (stored 0%)
#   adding: output/92096.png (stored 0%)
#   adding: output/92102.png (stored 0%)
#   adding: output/92129.png (stored 0%)
#   adding: output/92138.png (stored 0%)
#   adding: output/92142.png (stored 0%)
#   adding: output/92197.png (stored 0%)
#   adding: output/92206.png (stored 0%)
#   adding: output/92217.png (stored 0%)
#   adding: output/92311.png (stored 0%)
#   adding: output/92354.png (stored 0%)
#   adding: output/92376.png (stored 0%)
#   adding: output/92386.png (stored 0%)
#   adding: output/92401.png (stored 0%)
#   adding: output/92429.png (stored 0%)
#   adding: output/92437.png (stored 0%)
#   adding: output/92522.png (stored 0%)
#   adding: output/92536.png (stored 0%)
#   adding: output/92554.png (stored 0%)
#   adding: output/92584.png (stored 0%)
#   adding: output/92623.png (stored 0%)
#   adding: output/92667.png (stored 0%)
#   adding: output/92697.png (stored 0%)
#   adding: output/92727.png (stored 0%)
#   adding: output/92753.png (stored 0%)
#   adding: output/92764.png (stored 0%)
#   adding: output/92799.png (stored 0%)
#   adding: output/92814.png (stored 0%)
#   adding: output/92816.png (stored 0%)
#   adding: output/9288.png (stored 0%)
#   adding: output/92918.png (stored 0%)
#   adding: output/93011.png (stored 0%)
#   adding: output/93019.png (stored 0%)
#   adding: output/93076.png (stored 0%)
#   adding: output/93077.png (stored 0%)
#   adding: output/9309.png (stored 0%)
#   adding: output/93123.png (stored 0%)
#   adding: output/93129.png (stored 0%)
#   adding: output/93157.png (stored 0%)
#   adding: output/93163.png (stored 0%)
#   adding: output/93168.png (stored 0%)
#   adding: output/93175.png (stored 0%)
#   adding: output/93230.png (stored 0%)
#   adding: output/93268.png (stored 0%)
#   adding: output/93269.png (stored 0%)
#   adding: output/93285.png (stored 0%)
#   adding: output/93293.png (stored 0%)
#   adding: output/93308.png (stored 0%)
#   adding: output/93314.png (stored 0%)
#   adding: output/93378.png (stored 0%)
#   adding: output/93396.png (stored 0%)
#   adding: output/93409.png (stored 0%)
#   adding: output/93429.png (stored 0%)
#   adding: output/93433.png (stored 0%)
#   adding: output/93438.png (stored 0%)
#   adding: output/93457.png (stored 0%)
#   adding: output/93470.png (stored 0%)
#   adding: output/9347.png (stored 0%)
#   adding: output/93526.png (stored 0%)
#   adding: output/93544.png (stored 0%)
#   adding: output/93557.png (stored 0%)
#   adding: output/93575.png (stored 0%)
#   adding: output/93585.png (stored 0%)
#   adding: output/93599.png (stored 0%)
#   adding: output/935.png (stored 0%)
#   adding: output/93611.png (stored 0%)
#   adding: output/93698.png (stored 0%)
#   adding: output/93716.png (stored 0%)
#   adding: output/93722.png (stored 0%)
#   adding: output/93749.png (stored 0%)
#   adding: output/93750.png (stored 0%)
#   adding: output/9378.png (stored 0%)
#   adding: output/93798.png (stored 0%)
#   adding: output/93804.png (stored 0%)
#   adding: output/93812.png (stored 0%)
#   adding: output/93831.png (stored 0%)
#   adding: output/93887.png (stored 0%)
#   adding: output/93888.png (stored 0%)
#   adding: output/93918.png (stored 0%)
#   adding: output/93927.png (stored 0%)
#   adding: output/9392.png (stored 0%)
#   adding: output/93937.png (stored 0%)
#   adding: output/93972.png (stored 0%)
#   adding: output/94017.png (stored 0%)
#   adding: output/94037.png (stored 0%)
#   adding: output/94072.png (stored 0%)
#   adding: output/94089.png (stored 0%)
#   adding: output/9411.png (stored 0%)
#   adding: output/9412.png (stored 0%)
#   adding: output/94146.png (stored 0%)
#   adding: output/94154.png (stored 0%)
#   adding: output/94206.png (stored 0%)
#   adding: output/94209.png (stored 0%)
#   adding: output/94230.png (stored 0%)
#   adding: output/94248.png (stored 0%)
#   adding: output/94270.png (stored 0%)
#   adding: output/94307.png (stored 0%)
#   adding: output/94335.png (stored 0%)
#   adding: output/94342.png (stored 0%)
#   adding: output/94353.png (stored 0%)
#   adding: output/94366.png (stored 0%)
#   adding: output/94443.png (stored 0%)
#   adding: output/94456.png (stored 0%)
#   adding: output/94485.png (stored 0%)
#   adding: output/94502.png (stored 0%)
#   adding: output/94545.png (stored 0%)
#   adding: output/94587.png (stored 0%)
#   adding: output/9463.png (stored 0%)
#   adding: output/94641.png (stored 0%)
#   adding: output/94703.png (stored 0%)
#   adding: output/94741.png (stored 0%)
#   adding: output/94744.png (stored 0%)
#   adding: output/9474.png (stored 0%)
#   adding: output/94838.png (stored 0%)
#   adding: output/94849.png (stored 0%)
#   adding: output/9486.png (stored 0%)
#   adding: output/94885.png (stored 0%)
#   adding: output/94902.png (stored 0%)
#   adding: output/9490.png (stored 0%)
#   adding: output/94910.png (stored 0%)
#   adding: output/94962.png (stored 0%)
#   adding: output/94977.png (stored 0%)
#   adding: output/94983.png (stored 0%)
#   adding: output/95031.png (stored 0%)
#   adding: output/95063.png (stored 0%)
#   adding: output/95102.png (stored 0%)
#   adding: output/95117.png (stored 0%)
#   adding: output/95163.png (stored 0%)
#   adding: output/95177.png (stored 0%)
#   adding: output/95189.png (stored 0%)
#   adding: output/95250.png (stored 0%)
#   adding: output/95267.png (stored 0%)
#   adding: output/9526.png (stored 0%)
#   adding: output/95295.png (stored 0%)
#   adding: output/95356.png (stored 0%)
#   adding: output/95383.png (stored 0%)
#   adding: output/95432.png (stored 0%)
#   adding: output/95441.png (stored 0%)
#   adding: output/95453.png (stored 0%)
#   adding: output/95509.png (stored 0%)
#   adding: output/95522.png (stored 0%)
#   adding: output/9555.png (stored 0%)
#   adding: output/95667.png (stored 0%)
#   adding: output/95671.png (stored 0%)
#   adding: output/95693.png (stored 0%)
#   adding: output/95781.png (stored 0%)
#   adding: output/9578.png (stored 0%)
#   adding: output/95792.png (stored 0%)
#   adding: output/95835.png (stored 0%)
#   adding: output/95863.png (stored 0%)
#   adding: output/95878.png (stored 0%)
#   adding: output/95881.png (stored 0%)
#   adding: output/95897.png (stored 0%)
#   adding: output/9591.png (stored 0%)
#   adding: output/95920.png (stored 0%)
#   adding: output/95942.png (stored 0%)
#   adding: output/95954.png (stored 0%)
#   adding: output/95971.png (stored 0%)
#   adding: output/96013.png (stored 0%)
#   adding: output/96043.png (stored 0%)
#   adding: output/96045.png (stored 0%)
#   adding: output/96082.png (stored 0%)
#   adding: output/96107.png (stored 0%)
#   adding: output/96144.png (stored 0%)
#   adding: output/96155.png (stored 0%)
#   adding: output/96209.png (stored 0%)
#   adding: output/96230.png (stored 0%)
#   adding: output/96249.png (stored 0%)
#   adding: output/96256.png (stored 0%)
#   adding: output/96262.png (stored 0%)
#   adding: output/96269.png (stored 0%)
#   adding: output/96277.png (stored 0%)
#   adding: output/96289.png (stored 0%)
#   adding: output/96301.png (stored 0%)
#   adding: output/96310.png (stored 0%)
#   adding: output/96322.png (stored 0%)
#   adding: output/96336.png (stored 0%)
#   adding: output/96364.png (stored 0%)
#   adding: output/96367.png (stored 0%)
#   adding: output/96370.png (stored 0%)
#   adding: output/96403.png (stored 0%)
#   adding: output/96450.png (stored 0%)
#   adding: output/96453.png (stored 0%)
#   adding: output/96469.png (stored 0%)
#   adding: output/9647.png (stored 0%)
#   adding: output/96498.png (stored 0%)
#   adding: output/96508.png (stored 0%)
#   adding: output/96523.png (stored 0%)
#   adding: output/96543.png (stored 0%)
#   adding: output/96568.png (stored 0%)
#   adding: output/96621.png (stored 0%)
#   adding: output/96677.png (stored 0%)
#   adding: output/96680.png (stored 0%)
#   adding: output/96685.png (stored 0%)
#   adding: output/96696.png (stored 0%)
#   adding: output/9673.png (stored 0%)
#   adding: output/96741.png (stored 0%)
#   adding: output/96751.png (stored 0%)
#   adding: output/9675.png (stored 0%)
#   adding: output/9680.png (stored 0%)
#   adding: output/96817.png (stored 0%)
#   adding: output/96820.png (stored 0%)
#   adding: output/96888.png (stored 0%)
#   adding: output/96903.png (stored 0%)
#   adding: output/96971.png (stored 0%)
#   adding: output/96992.png (stored 0%)
#   adding: output/96999.png (stored 0%)
#   adding: output/97022.png (stored 0%)
#   adding: output/9703.png (stored 0%)
#   adding: output/97047.png (stored 0%)
#   adding: output/97069.png (stored 0%)
#   adding: output/97080.png (stored 0%)
#   adding: output/97128.png (stored 0%)
#   adding: output/97140.png (stored 0%)
#   adding: output/97168.png (stored 0%)
#   adding: output/97229.png (stored 0%)
#   adding: output/97234.png (stored 0%)
#   adding: output/97240.png (stored 0%)
#   adding: output/97260.png (stored 0%)
#   adding: output/97261.png (stored 0%)
#   adding: output/97292.png (stored 0%)
#   adding: output/97353.png (stored 0%)
#   adding: output/97366.png (stored 0%)
#   adding: output/97395.png (stored 0%)
#   adding: output/97425.png (stored 0%)
#   adding: output/97484.png (stored 0%)
#   adding: output/97511.png (stored 0%)
#   adding: output/97597.png (stored 0%)
#   adding: output/97732.png (stored 0%)
#   adding: output/97750.png (stored 0%)
#   adding: output/97754.png (stored 0%)
#   adding: output/97760.png (stored 0%)
#   adding: output/97789.png (stored 0%)
#   adding: output/97805.png (stored 0%)
#   adding: output/97817.png (stored 0%)
#   adding: output/97819.png (stored 0%)
#   adding: output/97822.png (stored 0%)
#   adding: output/97835.png (stored 0%)
#   adding: output/97836.png (stored 0%)
#   adding: output/97895.png (stored 0%)
#   adding: output/97897.png (stored 0%)
#   adding: output/97930.png (stored 0%)
#   adding: output/97943.png (stored 0%)
#   adding: output/97947.png (stored 0%)
#   adding: output/97971.png (stored 0%)
#   adding: output/97981.png (stored 0%)
#   adding: output/98005.png (stored 0%)
#   adding: output/98059.png (stored 0%)
#   adding: output/98066.png (stored 0%)
#   adding: output/98081.png (stored 0%)
#   adding: output/98099.png (stored 0%)
#   adding: output/98138.png (stored 0%)
#   adding: output/98141.png (stored 0%)
#   adding: output/98159.png (stored 0%)
#   adding: output/98171.png (stored 0%)
#   adding: output/98225.png (stored 0%)
#   adding: output/98247.png (stored 0%)
#   adding: output/98263.png (stored 0%)
#   adding: output/98267.png (stored 0%)
#   adding: output/98278.png (stored 0%)
#   adding: output/98296.png (stored 0%)
#   adding: output/98304.png (stored 0%)
#   adding: output/98348.png (stored 0%)
#   adding: output/98364.png (stored 0%)
#   adding: output/9839.png (stored 0%)
#   adding: output/98403.png (stored 0%)
#   adding: output/98414.png (stored 0%)
#   adding: output/98428.png (stored 0%)
#   adding: output/98433.png (stored 0%)
#   adding: output/98440.png (stored 0%)
#   adding: output/9849.png (stored 0%)
#   adding: output/98501.png (stored 0%)
#   adding: output/98513.png (stored 0%)
#   adding: output/98516.png (stored 0%)
#   adding: output/98574.png (stored 0%)
#   adding: output/98586.png (stored 0%)
#   adding: output/98601.png (stored 0%)
#   adding: output/98605.png (stored 0%)
#   adding: output/98622.png (stored 0%)
#   adding: output/98629.png (stored 0%)
#   adding: output/98641.png (stored 0%)
#   adding: output/98649.png (stored 0%)
#   adding: output/98657.png (stored 0%)
#   adding: output/98671.png (stored 0%)
#   adding: output/98675.png (stored 0%)
#   adding: output/98689.png (stored 0%)
#   adding: output/98753.png (stored 0%)
#   adding: output/98755.png (stored 0%)
#   adding: output/9877.png (stored 0%)
#   adding: output/987.png (stored 0%)
#   adding: output/98802.png (stored 0%)
#   adding: output/98824.png (stored 0%)
#   adding: output/98849.png (stored 0%)
#   adding: output/98909.png (stored 0%)
#   adding: output/98918.png (stored 0%)
#   adding: output/98985.png (stored 0%)
#   adding: output/99016.png (stored 0%)
#   adding: output/99022.png (stored 0%)
#   adding: output/9903.png (stored 0%)
#   adding: output/9904.png (stored 0%)
#   adding: output/99075.png (stored 0%)
#   adding: output/99080.png (stored 0%)
#   adding: output/99091.png (stored 0%)
#   adding: output/99095.png (stored 0%)
#   adding: output/99102.png (stored 0%)
#   adding: output/99139.png (stored 0%)
#   adding: output/99145.png (stored 0%)
#   adding: output/99153.png (stored 0%)
#   adding: output/99160.png (stored 0%)
#   adding: output/99193.png (stored 0%)
#   adding: output/99200.png (stored 0%)
#   adding: output/99208.png (stored 0%)
#   adding: output/99210.png (stored 0%)
#   adding: output/99261.png (stored 0%)
#   adding: output/99323.png (stored 0%)
#   adding: output/99327.png (stored 0%)
#   adding: output/9932.png (stored 0%)
#   adding: output/99365.png (stored 0%)
#   adding: output/99450.png (stored 0%)
#   adding: output/9947.png (stored 0%)
#   adding: output/99488.png (stored 0%)
#   adding: output/99494.png (stored 0%)
#   adding: output/99592.png (stored 0%)
#   adding: output/99605.png (stored 0%)
#   adding: output/99625.png (stored 0%)
#   adding: output/9968.png (stored 0%)
#   adding: output/99693.png (stored 0%)
#   adding: output/99697.png (stored 0%)
#   adding: output/99708.png (stored 0%)
#   adding: output/99712.png (stored 0%)
#   adding: output/99719.png (stored 0%)
#   adding: output/99729.png (stored 0%)
#   adding: output/99750.png (stored 0%)
#   adding: output/99758.png (stored 0%)
#   adding: output/99799.png (stored 0%)
#   adding: output/99802.png (stored 0%)
#   adding: output/9981.png (stored 0%)
#   adding: output/99821.png (stored 0%)
#   adding: output/99823.png (stored 0%)
#   adding: output/99829.png (stored 0%)
#   adding: output/99841.png (stored 0%)
#   adding: output/99883.png (stored 0%)
#   adding: output/99898.png (stored 0%)
#   adding: output/99912.png (stored 0%)
#   adding: output/99926.png (stored 0%)
#   adding: output/99938.png (stored 0%)
#   adding: output/embeddings.csv (deflated 56%)

# %% [markdown]
# # RESET

# %%
def model_stealing_reset():
    SERVER_URL = "http://34.71.138.79:9090"
    ENDPOINT = "/modelstealing/reset"
    URL = SERVER_URL + ENDPOINT

    TEAM_TOKEN = "DdE56eC1EvRwWcuy"

    response = requests.post(
        URL, headers={"token": TEAM_TOKEN}
    )

    if response.status_code == 200:
        print("Endpoint rested successfully")
    else:
        raise Exception(f"Request failed. Status code: {response.status_code}, content: {response.content}")

# %%
model_stealing_reset()
# Out:
# Endpoint rested successfully
